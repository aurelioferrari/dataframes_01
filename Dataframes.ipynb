# %%
import pandas as pd
import numpy as np

# %%
series = pd.Series([7, 3, 2, np.nan, 6, 9])

# %%
print(series)
# Out:
# 0    7.0
# 1    3.0
# 2    2.0
# 3    NaN
# 4    6.0
# 5    9.0
# dtype: float64

# %%
datas = pd.date_range('20180101', periods=6, freq='1Y')

# %%
print(datas)
# Out:
# DatetimeIndex(['2018-12-31', '2019-12-31', '2020-12-31', '2021-12-31',
#                '2022-12-31', '2023-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index = datas, columns=list('ABCD'))

print(df)
# Out:
#                    A         B         C         D
# 2018-12-31  1.084273 -1.449596  0.886461  0.792160
# 2019-12-31 -1.370578  0.306492  0.051090 -0.501368
# 2020-12-31 -0.369304 -1.526460  0.273787 -0.286938
# 2021-12-31 -0.326534 -1.342607 -0.423946  1.677127
# 2022-12-31  0.012365  0.585624  1.096509  0.562111
# 2023-12-31 -0.115198  0.094821  0.247315 -0.722281

# %%
df2 = pd.DataFrame({'A': 7,
                    'B': pd.Timestamp('20180101'),
                    'C': pd.Series(2, index=(range(0,3)), dtype='float32'),
                    'D': np.array([3] * 3, dtype='int32'),
                    'E': pd.Categorical(['test', 'train', 'test']),
                    'F': 'Python'})

# %%
df2
# Out:
#    A          B    C  D      E       F
# 0  7 2018-01-01  2.0  3   test  Python
# 1  7 2018-01-01  2.0  3  train  Python
# 2  7 2018-01-01  2.0  3   test  Python
